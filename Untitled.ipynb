# %%
from utils import authenticate

credentials, PROJECT_ID = authenticate()
print(PROJECT_ID)
# Out:
# dotted-music-460617-k2

# %%
import vertexai

REGION = "us-central1"

vertexai.init(
    project=PROJECT_ID,
    location=REGION,
    credentials=credentials
)

# %%
from google.cloud import bigquery

bq_client = bigquery.Client(
    project=PROJECT_ID,
    credentials=credentials
)

# %%
QUERY_TABLES = """
SELECT table_name
FROM `bigquery-public-data.stackoverflow.INFORMATION_SCHEMA.TABLES`
"""

query_job = bq_client.query(QUERY_TABLES)

for row in query_job:
    print(row.table_name)
# Out:
# posts_answers
# users
# posts_orphaned_tag_wiki
# posts_tag_wiki
# stackoverflow_posts
# posts_questions
# comments
# posts_tag_wiki_excerpt
# posts_wiki_placeholder
# posts_privilege_wiki
# post_history
# badges
# post_links
# tags
# votes
# posts_moderator_nomination

# %%
INSPECT_QUERY = """
SELECT *
FROM `bigquery-public-data.stackoverflow.posts_questions`
LIMIT 3
"""

import pandas as pd

query_job = bq_client.query(INSPECT_QUERY)

df = query_job.result().to_arrow().to_pandas()
df.head()
# Out:
#          id                                              title  \
# 0  67189485  Kafka Connect Elasticsearch Sink Connector wit...
# 1  67212745  Flutter - Could not find the correct Provider<...
# 2  67225222              which post-hoc test after welch-anova
#
#                                                 body  accepted_answer_id  \
# 0  <p>I am trying to workout a Kafka Connect Sink...                 NaN
# 1  <p>I'm using both BlocProvider &amp; ChangeNot...                 NaN
# 2  <p>i´m doing the statistical evaluation for my...                 NaN
#
#    answer_count  comment_count community_owned_date  \
# 0             1              0                  NaT
# 1             1              0                  NaT
# 2             0              0                  NaT
#
#                      creation_date  favorite_count  \
# 0 2021-04-21 04:54:34.827000+00:00             NaN
# 1 2021-04-22 11:52:08.667000+00:00             NaN
# 2 2021-04-23 06:49:00.640000+00:00             NaN
#
#                 last_activity_date                   last_edit_date  \
# 0 2021-04-21 08:41:59.440000+00:00                              NaT
# 1 2022-02-10 16:54:51.983000+00:00 2022-02-10 16:54:51.983000+00:00
# 2 2021-04-23 06:49:00.640000+00:00                              NaT
#
#   last_editor_display_name  last_editor_user_id owner_display_name  \
# 0                     None                  NaN               None
# 1                     None            4294399.0               None
# 2                     None                  NaN               None
#
#    owner_user_id parent_id  post_type_id  score  \
# 0         945034      None             1      0
# 1       15355065      None             1      0
# 2       15745361      None             1      1
#
#                                                 tags  view_count
# 0    elasticsearch|apache-kafka|apache-kafka-connect         256
# 1  flutter|flutter-provider|flutter-bloc|flutter-...         256
# 2                               anova|letter|posthoc         256

# %%
QUERY = """
SELECT
    CONCAT(q.title, q.body) AS input_text,
    a.body AS output_text
FROM
    `bigquery-public-data.stackoverflow.posts_questions` q
JOIN
    `bigquery-public-data.stackoverflow.posts_answers` a
ON
    q.accepted_answer_id = a.id
WHERE
    q.accepted_answer_id IS NOT NULL
    AND REGEXP_CONTAINS(q.tags, "python")
    AND a.creation_date >= "2020-01-01"
LIMIT 10000
"""

query_job = bq_client.query(QUERY)
df = query_job.result().to_arrow().to_pandas()
df.head(2)
# Out:
#                                           input_text  \
# 0  How to pass initializing file for vocabulary t...
# 1  Correct way to define an apache beam pipepline...
#
#                                          output_text
# 0  <p>For the Inference to work from any PC, the ...
# 1  <p>As pointed out by Yichi Zhang, <code>Pipeli...

# %%
INSTRUCTION_TEMPLATE = """Please answer the following Stackoverflow question on Python.
Answer it like you are a developer answering Stackoverflow questions.

Stackoverflow question:
"""

df["input_text_instruct"] = INSTRUCTION_TEMPLATE + df["input_text"]

# %%
from sklearn.model_selection import train_test_split

train, evaluation = train_test_split(
    df,
    test_size=0.2,
    random_state=42
)

# %%
import datetime

date = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

cols = ["input_text_instruct", "output_text"]

train.to_json(
    f"tune_data_stack_overflow_python_qa-{date}.jsonl",
    orient="records",
    lines=True
)

evaluation.to_json(
    f"tune_eval_data_stack_overflow_python_qa-{date}.jsonl",
    orient="records",
    lines=True
)
